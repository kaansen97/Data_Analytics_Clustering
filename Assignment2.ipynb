# %%
import pandas as pd
import plotly.express as px
import numpy as np

# %% [markdown]
# #Turning txt file into csv version

# %%
df=pd.read_csv('/content/docword.enron_header.txt',sep=" ")
df2=pd.read_csv('/content/docword.kos_header.txt',sep=" ")
df3=pd.read_csv('/content/docword.nips_header.txt',sep=" ")
df4=pd.read_csv('/content/docword.nytimes_header.txt',sep=" ")
vocab_nips=pd.read_csv('/content/vocab.nips.txt',sep=" ")
vocab_enron=pd.read_csv('/content/vocab.enron.txt',sep=" ")
vocab_kos=pd.read_csv('/content/vocab.kos.txt',sep=" ")
vocab_ny=pd.read_csv('/content/vocab.nytimes.txt',sep=" ")

# %%
df.to_csv(r'/content/docword.enron.csv')
df2.to_csv(r'/content/docword.kos.csv')
df3.to_csv(r'/content/docword.nips.csv')
df4.to_csv(r'/content/docword.nytimes.csv')
vocab_enron.to_csv(r'/content/vocab.enron.csv')
vocab_kos.to_csv(r'/content/vocab.kos.csv')
vocab_nips.to_csv(r'/content/vocab.nips.csv')
vocab_ny.to_csv(r'/content/vocab.ny.csv')

# %% [markdown]
# #Reading csv file again

# %%
df=pd.read_csv('/content/docword.enron.csv')
df2=pd.read_csv('/content/docword.kos.csv')
df3=pd.read_csv('/content/docword.nips.csv')
df4=pd.read_csv('/content/docword.nytimes.csv')
vocab_enron=pd.read_csv('/content/vocab.enron.csv')
vocab_kos=pd.read_csv('/content/vocab.kos.csv')
vocab_nips=pd.read_csv('/content/vocab.nips.csv')
vocab_ny=pd.read_csv('/content/vocab.ny.csv')

# %% [markdown]
# #Dropping innecessary columns after Reading

# %%
df.pop(df.columns[0])
df.dropna(inplace=True)
df
# Out:
#        Article_ID  Word_ID  Occurence_Number
# 0               1    118.0               1.0
# 1               1    285.0               1.0
# 2               1   1229.0               1.0
# 3               1   1688.0               1.0
# 4               1   2068.0               1.0
# ...           ...      ...               ...
# 54295         996  17764.0               1.0
# 54296         996  19425.0               1.0
# 54297         996  20262.0               2.0
# 54298         996  23815.0               1.0
# 54299         996  23998.0               1.0
#
# [54300 rows x 3 columns]

# %%
df2.pop(df2.columns[0])
df2.dropna(inplace=True)
df2
# Out:
#        Article_ID  Word_ID  Occurence_Number
# 0               1       61               2.0
# 1               1       76               1.0
# 2               1       89               1.0
# 3               1      211               1.0
# 4               1      296               1.0
# ...           ...      ...               ...
# 63484         645     4095               2.0
# 63485         645     4206               2.0
# 63486         645     4217               2.0
# 63487         645     4243               1.0
# 63488         645     4260               1.0
#
# [63489 rows x 3 columns]

# %%
df3.pop(df3.columns[0])
df3.dropna(inplace=True)
df3
# Out:
#        Article_ID  Word_ID  Occurence_Number
# 0               1      2.0               1.0
# 1               1     39.0               1.0
# 2               1     42.0               3.0
# 3               1     77.0               1.0
# 4               1     95.0               1.0
# ...           ...      ...               ...
# 64997         132   4605.0               1.0
# 64998         132   4987.0               5.0
# 64999         132   5024.0               1.0
# 65000         132   5059.0               2.0
# 65001         132   5063.0               1.0
#
# [65002 rows x 3 columns]

# %%
df4.pop(df4.columns[0])
df4.dropna(inplace=True)
df4
# Out:
#        Article_ID  Word_ID  Occurence_Number
# 0               1    413.0               1.0
# 1               1    534.0               1.0
# 2               1   2340.0               1.0
# 3               1   2806.0               1.0
# 4               1   3059.0               1.0
# ...           ...      ...               ...
# 49727         218  38646.0               1.0
# 49728         218  38670.0               1.0
# 49729         218  38755.0               1.0
# 49730         218  38886.0               1.0
# 49731         218  38901.0               1.0
#
# [49732 rows x 3 columns]

# %%
vocab_enron.pop(vocab_enron.columns[0])
vocab_enron.dropna(inplace=True)
vocab_enron
# Out:
#             Words
# 0             aaa
# 1            aaas
# 2         aactive
# 3      aadvantage
# 4           aaker
# ...           ...
# 28097       zshop
# 28098    zufferli
# 28099       zukav
# 28100      zurich
# 28101      zycher
#
# [28101 rows x 1 columns]

# %%
vocab_kos.pop(vocab_kos.columns[0])
vocab_kos.dropna(inplace=True)
vocab_kos
# Out:
#            Words
# 0           aarp
# 1        abandon
# 2      abandoned
# 3     abandoning
# 4            abb
# ...          ...
# 6901    zimbabwe
# 6902       zogby
# 6903      zogbys
# 6904        zone
# 6905       zones
#
# [6906 rows x 1 columns]

# %%
vocab_nips.pop(vocab_nips.columns[0])
vocab_nips.dropna(inplace=True)
vocab_nips
# Out:
#            Words
# 0            a2i
# 1            aaa
# 2           aaai
# 3           aapo
# 4            aat
# ...          ...
# 12414     zucker
# 12415        zue
# 12416        zur
# 12417     zurich
# 12418  zwislocki
#
# [12418 rows x 1 columns]

# %%
vocab_ny.pop(vocab_ny.columns[0])
vocab_ny.dropna(inplace=True)
vocab_ny
# Out:
#                                   Words
# 0                                   aah
# 1                                 aahed
# 2                                 aaron
# 3                                 aback
# 4                                abacus
# ...                                 ...
# 62249       zzz_financial_research_corp
# 62250            zzz_financial_services
# 62251     zzz_financial_services_agency
# 62252  zzz_financial_services_committee
# 62253                zzz_financial_time
#
# [62252 rows x 1 columns]

# %% [markdown]
# ##Renaming Article_ID to avoid collision

# %%
df=df.assign(From='enron')
df
# Out:
#        Article_ID  Word_ID  Occurence_Number   From
# 0               1    118.0               1.0  enron
# 1               1    285.0               1.0  enron
# 2               1   1229.0               1.0  enron
# 3               1   1688.0               1.0  enron
# 4               1   2068.0               1.0  enron
# ...           ...      ...               ...    ...
# 54295         996  17764.0               1.0  enron
# 54296         996  19425.0               1.0  enron
# 54297         996  20262.0               2.0  enron
# 54298         996  23815.0               1.0  enron
# 54299         996  23998.0               1.0  enron
#
# [54300 rows x 4 columns]

# %%
df2=df2.assign(From='kos')
df2
# Out:
#        Article_ID  Word_ID  Occurence_Number From
# 0               1       61               2.0  kos
# 1               1       76               1.0  kos
# 2               1       89               1.0  kos
# 3               1      211               1.0  kos
# 4               1      296               1.0  kos
# ...           ...      ...               ...  ...
# 63484         645     4095               2.0  kos
# 63485         645     4206               2.0  kos
# 63486         645     4217               2.0  kos
# 63487         645     4243               1.0  kos
# 63488         645     4260               1.0  kos
#
# [63489 rows x 4 columns]

# %%
df3=df3.assign(From='nips')
df3
# Out:
#        Article_ID  Word_ID  Occurence_Number  From
# 0               1      2.0               1.0  nips
# 1               1     39.0               1.0  nips
# 2               1     42.0               3.0  nips
# 3               1     77.0               1.0  nips
# 4               1     95.0               1.0  nips
# ...           ...      ...               ...   ...
# 64997         132   4605.0               1.0  nips
# 64998         132   4987.0               5.0  nips
# 64999         132   5024.0               1.0  nips
# 65000         132   5059.0               2.0  nips
# 65001         132   5063.0               1.0  nips
#
# [65002 rows x 4 columns]

# %%
df4=df4.assign(From='nytimes')
df4
# Out:
#        Article_ID  Word_ID  Occurence_Number     From
# 0               1    413.0               1.0  nytimes
# 1               1    534.0               1.0  nytimes
# 2               1   2340.0               1.0  nytimes
# 3               1   2806.0               1.0  nytimes
# 4               1   3059.0               1.0  nytimes
# ...           ...      ...               ...      ...
# 49727         218  38646.0               1.0  nytimes
# 49728         218  38670.0               1.0  nytimes
# 49729         218  38755.0               1.0  nytimes
# 49730         218  38886.0               1.0  nytimes
# 49731         218  38901.0               1.0  nytimes
#
# [49732 rows x 4 columns]

# %% [markdown]
# ##Merging 8 DataFrames

# %%
final_df = pd.merge(df, vocab_enron,left_on="Word_ID", right_index=True, how='left')
final_df
# Out:
#        Article_ID  Word_ID  Occurence_Number   From           Words
# 0               1    118.0               1.0  enron        accessed
# 1               1    285.0               1.0  enron    additionally
# 2               1   1229.0               1.0  enron        aprilmay
# 3               1   1688.0               1.0  enron      authorizes
# 4               1   2068.0               1.0  enron            bask
# ...           ...      ...               ...    ...             ...
# 54295         996  17764.0               1.0  enron       ordinance
# 54296         996  19425.0               1.0  enron  president_bush
# 54297         996  20262.0               2.0  enron          rapper
# 54298         996  23815.0               1.0  enron        standoff
# 54299         996  23998.0               1.0  enron      stockbased
#
# [54300 rows x 5 columns]

# %%
final_df2 = pd.merge(df2, vocab_kos,left_on="Word_ID", right_index=True, how='left')
final_df2
# Out:
#        Article_ID  Word_ID  Occurence_Number From            Words
# 0               1       61               2.0  kos          actions
# 1               1       76               1.0  kos           adding
# 2               1       89               1.0  kos  administrations
# 3               1      211               1.0  kos           allied
# 4               1      296               1.0  kos          anxiety
# ...           ...      ...               ...  ...              ...
# 63484         645     4095               2.0  kos       nationwide
# 63485         645     4206               2.0  kos           nussle
# 63486         645     4217               2.0  kos              obl
# 63487         645     4243               1.0  kos            ocean
# 63488         645     4260               1.0  kos          offices
#
# [63489 rows x 5 columns]

# %%
final_df3 = pd.merge(df3, vocab_nips,left_on="Word_ID", right_index=True, how='left')
final_df3
# Out:
#        Article_ID  Word_ID  Occurence_Number  From        Words
# 0               1      2.0               1.0  nips         aaai
# 1               1     39.0               1.0  nips   abstracted
# 2               1     42.0               3.0  nips   abundances
# 3               1     77.0               1.0  nips    accounted
# 4               1     95.0               1.0  nips     achieved
# ...           ...      ...               ...   ...          ...
# 64997         132   4605.0               1.0  nips    grunewald
# 64998         132   4987.0               5.0  nips  hypothesize
# 64999         132   5024.0               1.0  nips        ideal
# 65000         132   5059.0               2.0  nips    ignorance
# 65001         132   5063.0               1.0  nips          ihc
#
# [65002 rows x 5 columns]

# %%
final_df4 = pd.merge(df4, vocab_ny,left_on="Word_ID", right_index=True, how='left')
final_df4
# Out:
#        Article_ID  Word_ID  Occurence_Number     From        Words
# 0               1    413.0               1.0  nytimes  actualmente
# 1               1    534.0               1.0  nytimes   admittedly
# 2               1   2340.0               1.0  nytimes    attempted
# 3               1   2806.0               1.0  nytimes       ballad
# 4               1   3059.0               1.0  nytimes    basically
# ...           ...      ...               ...      ...          ...
# 49727         218  38646.0               1.0  nytimes   supposedly
# 49728         218  38670.0               1.0  nytimes     sureness
# 49729         218  38755.0               1.0  nytimes    suspender
# 49730         218  38886.0               1.0  nytimes      swinger
# 49731         218  38901.0               1.0  nytimes       switch
#
# [49732 rows x 5 columns]

# %%
result = pd.concat([final_df, final_df2], ignore_index=True, sort=False)
result = pd.concat([result, final_df3], ignore_index=True, sort=False)
result = pd.concat([result, final_df4], ignore_index=True, sort=False)
result
# Out:
#         Article_ID  Word_ID  Occurence_Number     From         Words
# 0                1    118.0               1.0    enron      accessed
# 1                1    285.0               1.0    enron  additionally
# 2                1   1229.0               1.0    enron      aprilmay
# 3                1   1688.0               1.0    enron    authorizes
# 4                1   2068.0               1.0    enron          bask
# ...            ...      ...               ...      ...           ...
# 232518         218  38646.0               1.0  nytimes    supposedly
# 232519         218  38670.0               1.0  nytimes      sureness
# 232520         218  38755.0               1.0  nytimes     suspender
# 232521         218  38886.0               1.0  nytimes       swinger
# 232522         218  38901.0               1.0  nytimes        switch
#
# [232523 rows x 5 columns]

# %% [markdown]
# #Shuffle of Dataset

# %%
result = result.sample(frac=1).reset_index(drop=True)
result=result.dropna()
result
# Out:
#         Article_ID  Word_ID  Occurence_Number     From      Words
# 0              696  25804.0               2.0    enron     triple
# 1              507  10257.0               1.0    enron      games
# 2              292    510.0               1.0      kos       ball
# 3              119  13359.0               2.0  nytimes  eradicate
# 4               89   1395.0               2.0     nips     caller
# ...            ...      ...               ...      ...        ...
# 232518         458  27090.0               1.0    enron   waitlist
# 232519         209   8446.0               1.0    enron  eolbridge
# 232520         605  22780.0               1.0    enron    shooter
# 232521         169  22522.0               1.0  nytimes      linea
# 232522          36   5836.0              23.0     nips     kansas
#
# [229019 rows x 5 columns]

# %%
result.isna().sum()
# Out:
# Article_ID          0
# Word_ID             0
# Occurence_Number    0
# From                0
# Words               0
# dtype: int64

# %% [markdown]
# #Writing To CSV file

# %%
result.to_csv(r'/content/final_dataframe.csv')

# %% [markdown]
# #Taking Csv File again for Exploration and modelling

# %%
data=pd.read_csv(r'final_dataframe.csv')

# %%
data = data.drop('Unnamed: 0', axis=1)
data
# Out:
#         Article_ID  Word_ID  Occurence_Number     From      Words
# 0              696  25804.0               2.0    enron     triple
# 1              507  10257.0               1.0    enron      games
# 2              292    510.0               1.0      kos       ball
# 3              119  13359.0               2.0  nytimes  eradicate
# 4               89   1395.0               2.0     nips     caller
# ...            ...      ...               ...      ...        ...
# 229014         458  27090.0               1.0    enron   waitlist
# 229015         209   8446.0               1.0    enron  eolbridge
# 229016         605  22780.0               1.0    enron    shooter
# 229017         169  22522.0               1.0  nytimes      linea
# 229018          36   5836.0              23.0     nips     kansas
#
# [229019 rows x 5 columns]

# %% [markdown]
# # Explore and describe the data

# %%
import matplotlib.pyplot as plt
max_article_id = data["Article_ID"].max()
max_word_id = data["Word_ID"].max()

# Create a DataFrame with the maximum values
max_values_df = pd.DataFrame({"Column": ["Article_ID", "Word_ID"],
                              "Max_Value": [max_article_id, max_word_id]})

# Plot the bar chart with labeled values and different colors
plt.bar(max_values_df["Column"], max_values_df["Max_Value"], color=["blue", "orange"])
plt.xlabel("Column")
plt.ylabel("Max Value")
plt.title("Maximum Values of Article_ID and Word_ID")

# Label the values on the bars
for i, value in enumerate(max_values_df["Max_Value"]):
    plt.text(i, value, str(value), ha="center", va="bottom")

plt.show()

# %%
occurrence_stats = data["Occurence_Number"].describe()
# Print the descriptive statistics
print(occurrence_stats)
# Out:
# count    229019.000000
# mean          1.702448
# std           2.656477
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max         111.000000
# Name: Occurence_Number, dtype: float64

# %%
import matplotlib.pyplot as plt

# Plot histogram
plt.hist(data['Occurence_Number'], bins=10)
plt.xlabel('Occurence_Number')
plt.ylabel('Frequency')
plt.title('Histogram of Occurence_Number')
plt.show()

# Plot box plot
plt.boxplot(data['Occurence_Number'])
plt.xlabel('Occurence_Number')
plt.ylabel('Value')
plt.title('Box Plot of Occurence_Number')
plt.show()

# %%
# statistics
counts = data['From'].value_counts()
# Calculate percentage
percentages = counts / counts.sum() * 100
# Create a DataFrame of statistical results
statistics = pd.DataFrame({'Counts': counts, 'Percentage': percentages})
# print statistical results
print(statistics)
# Out:
#          Counts  Percentage
# nips      65001   28.382361
# kos       63487   27.721281
# enron     54300   23.709823
# nytimes   46231   20.186535

# %%
counts = [65001, 63487, 54300, 46231]
sources = ['nips', 'kos', 'enron', 'nytimes']
explode = (0.1, 0, 0, 0)  # If you need to highlight a certain part, you can adjust the explode parameter

# draw pie chart
plt.pie(counts, explode=explode, labels=sources, autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')  # Set the pie chart as a circle
plt.title("Percentage of Sources")

# display graphics
plt.show()

# %%
# Counts the number of occurrences of each word based on the 'Words' column
word_counts = data.groupby("Words")["Occurence_Number"].sum().reset_index()
word_counts = word_counts.sort_values(by="Occurence_Number", ascending=False)
print(word_counts)
# Out:
#             Words  Occurence_Number
# 14656    netxvork            3064.0
# 11205     inquiry            1713.0
# 14071     modeled            1402.0
# 21850  systematic            1362.0
# 2822   bushcheney            1275.0
# ...           ...               ...
# 20349      sloppy               1.0
# 20348   slopeside               1.0
# 10106      helmed               1.0
# 10108     helming               1.0
# 25514  zzz_fijian               1.0
#
# [25515 rows x 2 columns]

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(background_color="white").generate_from_frequencies(dict(zip(word_counts["Words"], word_counts["Occurence_Number"])))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# # Cluster modeling

# %% [markdown]
# ## k-means

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.utils import resample
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import LabelEncoder
# Encode the 'From' column
label_encoder = LabelEncoder()
data['From_Encoded'] = label_encoder.fit_transform(data['From'])

# Print the encoded values and their corresponding original values
encoded_values = data['From_Encoded'].unique()
original_values = label_encoder.inverse_transform(encoded_values)

for encoded, original in zip(encoded_values, original_values):
    print(f"Encoded: {encoded} -> Original: {original}")
# Out:
# Encoded: 2 -> Original: nips
# Encoded: 0 -> Original: enron
# Encoded: 1 -> Original: kos
# Encoded: 3 -> Original: nytimes

# %%
# Construct the feature matrix
X = data[["Article_ID","Word_ID", "Occurence_Number","From_Encoded"]]
X_new = resample(X, n_samples=int(0.2 * len(X)), random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X_new[["Article_ID","Word_ID", "Occurence_Number"]],X_new[["From_Encoded"]], test_size=0.2, random_state=42)

# Print the shapes of the train and test sets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (36642, 3)
# X_test shape: (9161, 3)
# y_train shape: (36642, 1)
# y_test shape: (9161, 1)

# %%
# Finding the optimal number of clusters
max_clusters = 10  # Maximum number of clusters
best_cluster_count = 0
best_silhouette_score = -1
inertia = []
score=[]
for k in range(2, max_clusters + 1):
    # Construction of K-means model
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(X_train)

    # Calculation of contour coefficient
    silhouette_avg = silhouette_score(X_train, kmeans.labels_)
    score.append(silhouette_avg)
        # Calculate the total internal sum of squares
    inertia.append(kmeans.inertia_)
    # Select the number of clusters with the highest profile coefficients
    if silhouette_avg > best_silhouette_score:
        best_silhouette_score = silhouette_avg
        best_cluster_count = k
# Out:
# D:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# D:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# D:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# D:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
import matplotlib.pyplot as plt# Drawing the elbow
plt.plot(range(1, max_clusters ), inertia, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Total Within-Cluster Sum of Squares')
plt.title('Elbow Method')
plt.show()

# %%
# Set the number of clusters to 4
k = 4

# Construct the K-means model
kmeans = KMeans(n_clusters=4, init='k-means++', max_iter=200, n_init=20, random_state=0)
kmeans.fit(X_train)

# Compute silhouette score
silhouette_avg = silhouette_score(X_train, kmeans.labels_)

# Compute total within-cluster sum of squares
inertia = kmeans.inertia_

# Update best silhouette score and cluster count
if silhouette_avg > best_silhouette_score:
    best_silhouette_score = silhouette_avg
    best_cluster_count = k

# Plot the distribution of cluster centers and sample points
plt.scatter(X_train.iloc[:, 0], X_train.iloc[:, 1], c=kmeans.labels_, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='x', color='red')
plt.xlabel('Article_ID')
plt.ylabel('Word_ID')
plt.title('Distribution of Cluster Centers and Sample Points')
plt.show()

# %% [markdown]
# ## Agglomerative Cluster

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
# Find the optimal number of clusters
max_clusters = 5  # Maximum number of clusters
best_cluster_count = 0
best_silhouette_score = -1
silhouette_scores = []
for k in range(2, max_clusters + 1):
    # Constructing hierarchical clustering models (cohesive clustering)
    hierarchical = AgglomerativeClustering(n_clusters=k)
    hierarchical.fit(X_train)

    # Calculation of contour coefficient
    silhouette_avg = silhouette_score(X_train, hierarchical.labels_)
    silhouette_scores.append(silhouette_avg)
    # Select the number of clusters with the highest profile coefficients
    if silhouette_avg > best_silhouette_score:
        best_silhouette_score = silhouette_avg
        best_cluster_count = k

# Output the optimal number of clusters
print("Best number of clusters:", best_cluster_count)
# Out:
# Best number of clusters: 2

# %%
plt.plot(range(2, max_clusters + 1), silhouette_scores, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette score')
plt.title('Silhouette Score for Different Cluster Numbers')
plt.show()

# %%
# Building hierarchical clustering Model
hierarchical = AgglomerativeClustering(n_clusters=4)
hierarchical.fit(X_train)
labels = hierarchical.labels_
plt.scatter(X_train["Article_ID"], X_train["Word_ID"], c=labels)
plt.scatter(hierarchical.children_[:, 0], hierarchical.children_[:, 1], c='r', marker='o', label='Cluster centers')
plt.xlabel("Article_ID")
plt.ylabel("Word_ID")
plt.title("Clustering Results")
plt.legend()
plt.show()

# %% [markdown]
# ## GMM Cluster

# %%
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score

max_clusters = 5  # Maximum number of clusters
best_cluster_count = 0
best_silhouette_score = -1
silhouette_scores2 = []

for k in range(2, max_clusters + 1):
    # Building the GMM model
    gmm = GaussianMixture(n_components=k)
    gmm.fit(X_train)

    # Calculation of contour coefficient
    silhouette_avg = silhouette_score(X_train, gmm.predict(X_train))
    silhouette_scores2.append(silhouette_avg)

    # Select the number of clusters with the highest profile coefficients
    if silhouette_avg > best_silhouette_score:
        best_silhouette_score = silhouette_avg
        best_cluster_count = k

# Output the optimal number of clusters
print("Best number of clusters:", best_cluster_count)
# Out:
# Best number of clusters: 2

# %%
plt.plot(range(2, max_clusters + 1), silhouette_scores2, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette score')
plt.title('Silhouette Score for Different Cluster Numbers')
plt.show()

# %%
# Construct the GMM model
gmm = GaussianMixture(n_components=2)
gmm.fit(X_train)

# Compute silhouette score
silhouette_avg = silhouette_score(X_train, gmm.predict(X_train))

# Update best silhouette score and cluster count
best_silhouette_score = silhouette_avg
best_cluster_count = k

# Plot the distribution of cluster centers and sample points
plt.scatter(X_train.iloc[:, 0], X_train.iloc[:, 1], c=gmm.predict(X_train), cmap='viridis')
plt.scatter(gmm.means_[:, 0], gmm.means_[:, 1], marker='x', color='red')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Distribution of Cluster Centers and Sample Points')
plt.show()

# Output the best number of clusters
print("Best number of clusters:", best_cluster_count)
# Out:
# Best number of clusters: 5

# %% [markdown]
# # Indicator evaluation

# %%
predicted_clusters = kmeans.predict(X_test)

# %%
predicted_clusters
# Out:
# array([1, 0, 3, ..., 3, 3, 1])

# %%
y_test
# Out:
# array([3, 2, 0, ..., 2, 2, 0])

# %%
from sklearn.metrics import adjusted_rand_score
import numpy as np

# Flatten the y_test_modified array
y_test_modified = np.ravel(y_test_modified)

# Predict cluster labels for test data
predicted_labels = kmeans.predict(X_test)

# Compute Adjusted Rand Index (ARI)
ari = adjusted_rand_score(y_test_modified, predicted_labels)

print("Adjusted Rand Index (ARI):", ari)
# Out:
# Adjusted Rand Index (ARI): 0.5603404818409771
